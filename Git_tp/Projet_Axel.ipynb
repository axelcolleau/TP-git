# %% [markdown]
# 1) interface graphique

# %% [markdown]
# on utilise le module Tkinter module deja installer par defaut sur python.

# %%
import tkinter as tk
from tkinter import ttk #placement controler des widget

# %%
#on cree une fenetre
fenetre=tk.Tk()
fenetre.title("ceci est ma premiere fenetre") #titre
fenetre.geometry("600x400") #taille fenetre

fenetre.mainloop()

# %%
#placer des widget

fenetre=tk.Tk()
fenetre.title("tester les widget")
fenetre.geometry("640x480")
def texte():
    text.entry
                        


texte_affiche=tk.Label(fenetre,text="je veux afficher du texte")
texte_affiche.pack()


def quit():
    fenetre.destroy()

mon_bouton=tk.Button(fenetre,text="clique ici",command= quit)
mon_bouton.pack()


fenetre.mainloop()

# %%
fenetre=tk.Tk()
fenetre.title("Résultats du semestre")
fenetre.geometry("400x600")

frm=ttk.Frame(fenetre)
frm.grid()


def action():
    aff=ttk.Label(fenetre,text="vous avez cliqué !!")
    aff.grid()
    
def retour():
    a=saisie.get()
    affiche=ttk.Label(fenetre,text=float(a)+17)
    affiche.grid()
#ou on peut faire r=tk.Label(fenetre,text=saisie.get())
                 #r.pack()
    
affich1=ttk.Label(fenetre,text="Petit rappel")
affich1.grid(column=0,row=2,pady=5)

affich2=ttk.Label(fenetre,text="Petit rappel")
affich2.grid()

btn1=ttk.Button(fenetre,text="cliquez ici",command=action)
btn1.grid()

saisie=ttk.Entry(fenetre)
saisie.grid(column=1,row=10,pady=10) #colonne, ligne, espace

btn2=ttk.Button(fenetre,text="validez",command=retour)
btn2.grid(column=2,row=10)

fenetre.mainloop()

# %%
from PIL import Image, ImageTK

fenetre=tk.Tk()
fenetre.title("Insertion d'image")

img=Image.open("mon_shema.jpg")
img=img.resize((300,200))

photo=ImageTk.PhotoImage(img)

canvas = tk.Canvas(fenetre,witdh=300,height=200)
canvas.pack()

canvas.create_image(0,0,image=photo,anchor="nw")

fenetre.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from PIL import Image, ImageTK
#       3 fenetre=tk.Tk()
#       4 fenetre.title("Insertion d'image")
#
# ImportError: cannot import name 'ImageTK' from 'PIL' (C:\ProgramData\anaconda3\Lib\site-packages\PIL\__init__.py)

# %%
coef_ue1={
    'R101':10,
    'R102':10,
    'R103':7,
    'R104':7,
    'R105':0,
    'R106':5,
    'R107':0,
    'R108':6,
    'R109':0,
    'R110':5,
    'R111':4,
    'R112':2,
    'R113':5,
    'R114':5,
    'R115':0}

ressource=['R101','R102','R103','R104','R105','R106','R107','R108','R109','R110','R111','R112','R113','R114','R115']

c1=coef_ue1.values()

fenetre=tk.Tk()
fenetre.title("Résultats du semestre")
fenetre.geometry("500x600")

frm=ttk.Frame(fenetre)
frm.grid()
note=[]

def retour():
    for i,elt in enumerate(ressource):
        note.append(saisie_i.get())
    print(note)
    resultat_ue1=0
    for i,elt in enumerate(note):
            resultat_ue1 += note(i) * c1(i) / sum(coef_ue1.values())
    return resultat_ue1

affich1=ttk.Label(frm,text="Ressource en SAE")
affich1.grid(column=0,row=0)

affich2=ttk.Label(frm,text="Saisir les notes:")
affich2.grid(column=0,row=1)

for i,elements in enumerate(coef_ue1):
    affichR=ttk.Label(frm,text=elements)
    affichR.grid(column=0,row=2+i)

for i,elements in enumerate(ressource):
    saisie_i=ttk.Entry(frm)
    saisie_i.grid(column=1,row=2+i)
    

btn1=ttk.Button(frm,text="valider",command=retour)
btn1.grid(column=2,row=17)
    


fenetre.mainloop()
# Out:
# ['9', '9', '9', '9', '9', '9', '9', '9', '9', '9', '9', '9', '9', '9', '9']
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\colleaxe\AppData\Local\Temp\ipykernel_5636\1418086256.py", line 36, in retour
#     resultat_ue1 += note(i) * c1(i) / sum(coef_ue1.values())
#                     ~~~~^^^
# TypeError: 'list' object is not callable
